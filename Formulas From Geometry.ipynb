# %% [markdown]
# # Formulas From Geometry

# %%
# import required packages at the top of the script!
import sympy as sym
import numpy as np
from IPython.display import display, Math
import matplotlib.pyplot as plt

# %% [markdown]
# ### Triangle

# %%
x = 4
y = 5

# basic plotting a red dot
#plt.plot(x,y,'ro')

font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,7,0,6])
plt.grid()

# now add lines
plt.plot([1,4],[1,5],'r')
plt.plot([1,6],[1,1],'r')
plt.plot([4,6],[5,1],'r')
plt.plot([4,4],[5,1],'k--')
plt.text(3.6, 2.7, 'h', fontdict=font)
plt.text(2.2, 3.1, 'c', fontdict=font)
plt.text(5.2, 3.1, 'a', fontdict=font)
plt.text(3.4, .6, 'b', fontdict=font)

f1 = '$h = \\alpha * sin(\\theta)$'
plt.text(7.2, 5.5, f1, fontdict=font)
plt.text(7.2, 4.6, '$area = 1/2*b*h$', fontdict=font)
plt.text(7.2, 3.6, '$C^2 = a^2*b^2 - 2ab * cos(\\theta)$', fontdict=font)
#plt.plot([0,0],[1,6],'g')


plt.show()

# %%
x = 4
y = 5

# basic plotting a red dot
#plt.plot(x,y,'ro')

font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,7,0,6])
plt.grid()

# now add lines
plt.plot([1,4],[1,5],'r')
plt.plot([1,4],[1,1],'r')
plt.plot([4,4],[5,1],'r')
plt.text(2.1, 3.1, 'c', fontdict=font)
plt.text(4.2, 3.1, 'a', fontdict=font)
plt.text(2.4, .6, 'b', fontdict=font)

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{  Right Triangle}'
display(Math(sym.latex(in1)))
in2 = fquad + 'c^2 = a^2 + b^2'
display(Math(sym.latex(in2)))
#plt.plot([0,0],[1,6],'g')


plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{  Right Triangle}$
# $\displaystyle \quad \quad \quad \quad c^2 = a^2 + b^2$

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,7,0,6])
plt.grid()

# now add lines
plt.plot([2,4],[1,5],'r')
plt.plot([2,6],[1,1],'r')
plt.plot([4,6],[5,1],'r')
plt.plot([4,4],[5,1],'k--')
plt.text(3.6, 2.7, 'h', fontdict=font)
plt.text(2.4, 3.1, 's', fontdict=font)
plt.text(5.2, 3.1, 's', fontdict=font)
plt.text(3.4, .6, 's', fontdict=font)

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{  Equlateral Triangle}'
display(Math(sym.latex(in1)))
in2 = fquad + 'h = \\frac{\\sqrt(3s)}{2}'
display(Math(sym.latex(in2)))
in3 = fquad + 'Area = \\frac{\\sqrt(3x^2)}{4}'
display(Math(sym.latex(in3)))
plt.text(7.2, 4.6, '$h = sin(\\theta)$', fontdict=font)
plt.text(7.2, 3.6, '$C^2 = a^2*b^2 - 2ab * cos(\\theta)$', fontdict=font)
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{  Equlateral Triangle}$
# $\displaystyle \quad \quad \quad \quad h = \frac{\sqrt(3s)}{2}$
# $\displaystyle \quad \quad \quad \quad Area = \frac{\sqrt(3x^2)}{4}$

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,7,0,6])
plt.grid()

# now add lines
plt.plot([2,1],[1,4],'r')
plt.plot([2,6],[1,1],'r')
plt.plot([5,6],[4,1],'r')
plt.plot([1,5],[4,4],'r')

plt.plot([5,5],[4,1],'k--')
plt.text(4.6, 2.4, 'h', fontdict=font)
plt.text(3.4, .6, 'b', fontdict=font)

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{  Parallelogram}'
display(Math(sym.latex(in1)))
in3 = fquad + 'Area = bh'
display(Math(sym.latex(in3)))
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{  Parallelogram}$
# $\displaystyle \quad \quad \quad \quad Area = bh$

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,7,0,6])
plt.grid()

# now add lines
plt.plot([1,2],[1,5],'b')
plt.plot([1,6],[1,1],'b')
plt.plot([4,6],[5,1],'b')
plt.plot([2,4],[5,5],'b')

plt.plot([4,4],[5,1],'k--')
plt.text(3.6, 2.7, 'h', fontdict=font)
plt.text(3.4, .6, 'b', fontdict=font)
plt.text(3, 5.2, 'a', fontdict=font)

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{  Trapezoid}'
display(Math(sym.latex(in1)))
in3 = fquad + 'Area = \\frac{h}{2}(a + b)'
display(Math(sym.latex(in3)))
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{  Trapezoid}$
# $\displaystyle \quad \quad \quad \quad Area = \frac{h}{2}(a + b)$

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,7,0,6])
plt.grid()

# now add lines
plt.plot([1,1],[1,2],'b')
plt.plot([1,6],[1,1],'b')
plt.plot([6,6],[5,1],'b')
plt.plot([1,6],[2,5],'r')

plt.text(.6, 1.5, 'a', fontdict=font)
plt.text(6.2, 3.1, 'b', fontdict=font)
plt.text(3.4, .6, 'h', fontdict=font)

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Right Angle Trapezoid}'
display(Math(sym.latex(in1)))
in3 = fquad + 'Area = \\frac{h}{2}(a + b)'
display(Math(sym.latex(in3)))
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Right Angle Trapezoid}$
# $\displaystyle \quad \quad \quad \quad Area = \frac{h}{2}(a + b)$

# %%
# circle parameters
a = 1
b = 0
r = 3

# grid space
axlim = r + np.max((abs(a),abs(b)))
x = np.linspace(-axlim,axlim,100)
y = np.linspace(-axlim,axlim,100)
X,Y = np.meshgrid(x,y)

# create the function
Fxy = (X-a)**2 + (Y-b)**2 - r**2

# draw it as a contour
plt.contour(X,Y,Fxy,0)

# draw a dot in the center
plt.plot(a,b,'go')

# draw guide lines
plt.plot([-axlim,axlim],[0,0],'k--')
plt.plot([0,0],[-axlim,axlim],'k--')

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Circle}'
display(Math(sym.latex(in1)))
in3 = fquad + 'Area = \\pi r^2'
display(Math(sym.latex(in3)))
in3 = fquad + 'Circumference = 2\\pi r'
display(Math(sym.latex(in3)))

plt.grid()
plt.gca().set_aspect('equal')
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Circle}$
# $\displaystyle \quad \quad \quad \quad Area = \pi r^2$
# $\displaystyle \quad \quad \quad \quad Circumference = 2\pi r$

# %%
# circle parameters
a = 1
b = 1
r = 8

font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# grid space
axlim = r + np.max((abs(a),abs(b)))
x = np.linspace(8,axlim,100)
y = np.linspace(1,axlim,100)
X,Y = np.meshgrid(x,y)

# create the function
Fxy = (X-a)**2 + (Y-b)**2 - r**2

# draw it as a contour
plt.contour(X,Y,Fxy,0)

# draw a dot in the center
plt.plot(a,b,'go')

# draw guide lines
plt.plot([0,axlim+1],[0,0],'k--')
plt.plot([0,0],[0,axlim],'k--')

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Sector of a Circle}'
display(Math(sym.latex(in1)))
in3 = fquad + '\\theta \\text{ in radians}'
display(Math(sym.latex(in3)))
in3 = fquad + 'Area = \\frac{\\theta r^2}{2}'
display(Math(sym.latex(in3)))
in3 = fquad + '\\text{s = r}\\theta '
display(Math(sym.latex(in3)))

plt.text(9, 3, 's', fontdict=font)
plt.text(4.2, 3.4, 'r', fontdict=font)
plt.text(4.2, 3.4, 'r', fontdict=font)
plt.text(2.4, 1.2, 'θ', fontdict=font)
plt.plot([1,9],[1,1],'b')
plt.plot([1,8],[1,4.8],'b')


plt.grid()
plt.gca().set_aspect('equal')
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Sector of a Circle}$
# $\displaystyle \quad \quad \quad \quad \theta \text{ in radians}$
# $\displaystyle \quad \quad \quad \quad Area = \frac{\theta r^2}{2}$
# $\displaystyle \quad \quad \quad \quad \text{s = r}\theta $

# %%
# circle parameters
a = 1
b = 1
r = 3

font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# grid space
axlim = r + np.max((abs(a),abs(b)))
x = np.linspace(-axlim,axlim+1,100)
y = np.linspace(-axlim,axlim+1,100)
X,Y = np.meshgrid(x,y)

# create the function
Fxy = (X-a)**2 + (Y-b)**2 - r**2
plt.contour(X,Y,Fxy,0) # draw it as a contour

Fxy = (X-a)**2 + (Y-b)**2 - 2**2
plt.contour(X,Y,Fxy,0)

Fxy = (X-a)**2 + (Y-b)**2 - 2.5**2
plt.contour(X,Y,Fxy,0,colors='y')

# draw a dot in the center
plt.plot(a,b,'go')

# draw guide lines
plt.plot([-axlim,axlim+1],[0,0],'k--')
plt.plot([0,0],[-axlim,axlim+1],'k--')

plt.plot([4,1],[1,1],'b--')
plt.plot([1,2.44],[1,2.42],'b--')

plt.plot([-1.3,1],[-.1,1],'r--')
plt.plot([-2,-1],[1,1],'r--')

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Circular Ring}'
display(Math(sym.latex(in1)))
in3 = fquad + 'p = \\text{ average radius}'
display(Math(sym.latex(in3)))
in3 = fquad + 'w = \\text{ width of ring}'
display(Math(sym.latex(in3)))

plt.text(1.8, .4, 'R', fontdict=font)
plt.text(1.3, 1.8, 'r', fontdict=font)

plt.text(-.6, .65, 'p', fontdict=font)
plt.text(-1.7, 1.2, 'w', fontdict=font)

in3 = fquad + 'Area = \\pi\\text{(R^2 - r^2) = 2πpw}'
display(Math(sym.latex(in3)))

plt.grid()
plt.gca().set_aspect('equal')
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Circular Ring}$
# $\displaystyle \quad \quad \quad \quad p = \text{ average radius}$
# $\displaystyle \quad \quad \quad \quad w = \text{ width of ring}$
# $\displaystyle \quad \quad \quad \quad Area = \pi\text{(R^2 - r^2) = 2πpw}$

# %%
import numpy as np
import matplotlib
from matplotlib.patches import Wedge
from matplotlib.collections import PatchCollection
import matplotlib.pyplot as plt

font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 17,
        }


fig, ax = plt.subplots(figsize=[6,6])
w1 = PatchCollection([Wedge((.1,.1), .8, 0, 36)], color='b', alpha=0.2)
w2 = PatchCollection([Wedge((.1,.1), .6, 0, 36)], color='g', alpha=0.4)
ax.add_collection(w1)
ax.add_collection(w2)
ax.set_aspect('equal', 'box')

plt.text(.42, .4, 'r', fontdict=font)
plt.text(.21, .12, 'θ', fontdict=font)
plt.text(.9, .3, 's', fontdict=font)
plt.text(.05, .9, '          Sector of a Circular Ring', fontdict=font)
plt.text(.05, .8, 'p = average radius', fontdict=font)
plt.text(.05, .7, 'w = width of ring', fontdict=font)
plt.text(.05, .6, 'θ in radians', fontdict=font)
plt.text(.05, .5, 'Area = θpw', fontdict=font)

plt.show()

# %%
fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + fquad + '\\text{Ellipse}'
display(Math(sym.latex(in1)))
in1 = '\\text{Circumference = 2π }\\sqrt \\frac{a^2 + b^2}{2}'
display(Math(sym.latex(in1)))

fig = plt.figure()
ax = fig.add_subplot(211, aspect='auto')
ax.fill(x, y, alpha=0.2, facecolor='blue',
        edgecolor='black', linewidth=1, zorder=1)

e1 = patches.Arc((xcenter, ycenter), width, height,
                 angle=angle, linewidth=2, fill=False, zorder=2)

ax.add_patch(e1)
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \quad \quad \quad \quad \text{Ellipse}$
# $\displaystyle \text{Circumference = 2π }\sqrt \frac{a^2 + b^2}{2}$

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy.linalg import norm
import pylab as plt

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')


def truncated_cone(p0, p1, R0, R1, color):
    # vector in direction of axis
    v = p1 - p0
    # find magnitude of vector
    mag = norm(v)
    # unit vector in direction of axis
    v = v / mag
    # make some vector not in the same direction as v
    not_v = np.array([1, 1, 0])
    if (v == not_v).all():
        not_v = np.array([0, 1, 0])
    # make vector perpendicular to v
    n1 = np.cross(v, not_v)
    # print n1,'\t',norm(n1)
    # normalize n1
    n1 /= norm(n1)
    # make unit vector perpendicular to v and n1
    n2 = np.cross(v, n1)
    # surface ranges over t from 0 to length of axis and 0 to 2*pi
    n = 80
    t = np.linspace(0, mag, n)
    theta = np.linspace(0, 2 * np.pi, n)
    # use meshgrid to make 2d arrays
    t, theta = np.meshgrid(t, theta)
    R = np.linspace(R0, R1, n)
    # generate coordinates for surface
    X, Y, Z = [p0[i] + v[i] * t + R *
               np.sin(theta) * n1[i] + R * np.cos(theta) * n2[i] for i in [0, 1, 2]]
    ax.plot_surface(X, Y, Z, color=color, linewidth=0, antialiased=False)


A0 = np.array([1, 3, 2])
A1 = np.array([8, 5, 9])
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.set_zlim(0, 10)
truncated_cone(A0, A1, 1, 5, 'blue')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.arange(-50.0, 50, 1)
y = np.arange(-50.0, 50, 1)
X, Y = np.meshgrid(x, y)
Z = (-4823.7 + np.sqrt(abs((4823.7 ** 2) - (4 * (-240.185) * ((-5692 * Y) - (240.185 * np.multiply(X, X))
                                                              - (240.185 * np.multiply(Y, Y)) - 57607.26)))) / np.float(
    2 * (-240.185)))

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + fquad + '\\text{Cone}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{A = area of base}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Volume = } \\frac{Ah}{3}'
display(Math(sym.latex(in1)))

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

# Set up the grid in polar
theta = np.linspace(0,2*np.pi,90)
r = np.linspace(0,3,40) # 0 or truncate
T, R = np.meshgrid(theta, r)

# Then calculate X, Y, and Z
X = R * np.sin(T)
Y = R * np.cos(T)
Z = -np.sqrt(X**2 + Y**2) + 3.4

# Set the Z values outside your range to NaNs so they aren't plotted
ax.plot_surface(X, Y, Z)

ax.set_zlim(0,3)

plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \quad \quad \quad \quad \text{Cone}$
# $\displaystyle \quad \quad \quad \quad \text{A = area of base}$
# $\displaystyle \quad \quad \quad \quad \text{Volume = } \frac{Ah}{3}$

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + fquad + '\\text{Right Circular Cone}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Volume = }\\frac{πr^2h}{3}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Lateral Surface Area = π r } \\sqrt{r^2 + h^2}'
display(Math(sym.latex(in1)))

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

# Set up the grid in polar
theta = np.linspace(0,2*np.pi,90)
r = np.linspace(0,3,40) # 0 or truncate
T, R = np.meshgrid(theta, r)

# Then calculate X, Y, and Z
X = R * np.sin(T)
Y = R * np.cos(T)
Z = -np.sqrt(X**2 + Y**2) + 3.4

# Set the Z values outside your range to NaNs so they aren't plotted
ax.plot_surface(X, Y, Z)

ax.set_zlim(0,3)

plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \quad \quad \quad \quad \text{Right Circular Cone}$
# $\displaystyle \quad \quad \quad \quad \text{Volume = }\frac{πr^2h}{3}$
# $\displaystyle \quad \quad \quad \quad \text{Lateral Surface Area = π r } \sqrt{r^2 + h^2}$

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Frustum of Right Circular Cone}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Volume = } \\frac{π(r^2 + rR + R^2)h}{3}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Lateral Surface Area = π s (R + r)}'
display(Math(sym.latex(in1)))

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

# Set up the grid in polar
theta = np.linspace(0,2*np.pi,90)
r = np.linspace(1.3,3,40) # 0 or truncate
T, R = np.meshgrid(theta, r)

# Then calculate X, Y, and Z
X = R * np.sin(T)
Y = R * np.cos(T)
Z = -np.sqrt(X**2 + Y**2) + 3.4

# Set the Z values outside your range to NaNs so they aren't plotted
ax.plot_surface(X, Y, Z)

ax.set_zlim(0,3)

plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Frustum of Right Circular Cone}$
# $\displaystyle \quad \quad \quad \quad \text{Volume = } \frac{π(r^2 + rR + R^2)h}{3}$
# $\displaystyle \quad \quad \quad \quad \text{Lateral Surface Area = π s (R + r)}$

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Right Circular Cylinder}'
display(Math(sym.latex(in1)))
in1 = fquad + 'Volume =  π r^2 h'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Lateral Surface Area = 2 π r h}'
display(Math(sym.latex(in1)))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Cylinder
x=np.linspace(-1, 1, 100)
z=np.linspace(-1, 1, 100)
Xc, Zc=np.meshgrid(x, z)
Yc = np.sqrt(1-Xc**2)

# Draw parameters
ax.plot_surface(Xc, Yc, Zc, alpha=0.3, color='blue')
ax.plot_surface(Xc, -Yc, Zc, alpha=0.3, color='blue')
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Right Circular Cylinder}$
# $\displaystyle \quad \quad \quad \quad Volume =  π r^2 h$
# $\displaystyle \quad \quad \quad \quad \text{Lateral Surface Area = 2 π r h}$

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Sphere}'
display(Math(sym.latex(in1)))
in1 = fquad + 'Volume =  \\frac{4\\space π\\space r^3}{3}'
display(Math(sym.latex(in1)))
in1 = fquad + '\\text{Surface Area } = 4\\space  π\\space  r^2'
display(Math(sym.latex(in1)))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, color='b')

plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Sphere}$
# $\displaystyle \quad \quad \quad \quad Volume =  \frac{4\space π\space r^3}{3}$
# $\displaystyle \quad \quad \quad \quad \text{Surface Area } = 4\space  π\space  r^2$

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

# set axis limits
plt.axis('square') # order matters
plt.axis([0,11,0,11])
plt.grid()
# draw a dot in the center
#plt.plot(a,b,'go')

fquad = '\\quad \\quad \\quad \\quad '
in1 = fquad + '\\text{Wedge}'
display(Math(sym.latex(in1)))
in3 = fquad + '\\text{A = area of upper face}'
display(Math(sym.latex(in3)))
in3 = fquad + '\\text{B = area of base}'
display(Math(sym.latex(in3)))
in3 = fquad + '\\text{A = B sec }(\\theta)'
display(Math(sym.latex(in3)))

plt.text(5, 1.8, 'B', fontdict=font)
plt.text(4.2, 3.8, 'A', fontdict=font)
plt.text(2.6, 1.2, 'θ', fontdict=font)
plt.plot([1,7],[1,1],'b')
plt.plot([1,7],[1,5],'b')
plt.plot([7,7],[1,5],'b')
plt.plot([9,7],[2,1],'b')
plt.plot([9,7],[6,5],'b')
plt.plot([9,9],[2,6],'b')

plt.plot([2.6,9],[1.82,6],'k--')
plt.plot([1,2.6],[1,1.8],'k--')

plt.grid()
plt.gca().set_aspect('equal')
plt.show()
# Out:
# $\displaystyle \quad \quad \quad \quad \text{Wedge}$
# $\displaystyle \quad \quad \quad \quad \text{A = area of upper face}$
# $\displaystyle \quad \quad \quad \quad \text{B = area of base}$
# $\displaystyle \quad \quad \quad \quad \text{A = B sec }(\theta)$
